# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import jv

# %%
x = np.linspace(0, 1, 100)
m = 4
plt.plot(x, jv(0, m*x), label='J0')
plt.plot(x, jv(1, m*x), label='J1') 
plt.plot(x, jv(2, m*x), label='J2')


#w to dbm
x = 
print(x**2)
